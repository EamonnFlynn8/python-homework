# %%
# Import the pathlib and csv library
from pathlib import Path
import csv

# Initialize the metric variables
count = 0
total = 0
average = 0
minimum = 0
maximum = 0
line_num = 0
total_change = 0
# Initialize lists to hold profitable and unprofitable months profits/losses
pnls = []

profitable_months = []

unprofitable_months = []

# %%
# Set the file path
csvpath = Path('C:/Users/Eamonn/Desktop/Resources/budget_data.csv')

# %%
with open(csvpath, 'r') as csvfile:

    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    csvreader = csv.reader(csvfile, delimiter=',')
    
    print(type(csvreader))

    # Read the header row first (skip this step if there is no header)
    csv_header = next(csvreader)
    line_num += 1
    # Print the header
    print(csv_header)
 # Read each row of data after the header
    for row in csvreader:
        # Print the row
        print(row)
        
        #Test to see if Date prints 
        date = row[0]
        print(date)
        
        #Create a list of all the months and make a pnls an integer in order to append it to a list 
        pnl = int(row[1])
        print(pnl)
        pnls.append(pnl)
# Out:
# <class '_csv.reader'>
# ['Date', 'Profit/Losses']
# ['Jan-2010', '867884']
# Jan-2010
# 867884
# ['Feb-2010', '984655']
# Feb-2010
# 984655
# ['Mar-2010', '322013']
# Mar-2010
# 322013
# ['Apr-2010', '-69417']
# Apr-2010
# -69417
# ['May-2010', '310503']
# May-2010
# 310503
# ['Jun-2010', '522857']
# Jun-2010
# 522857
# ['Jul-2010', '1033096']
# Jul-2010
# 1033096
# ['Aug-2010', '604885']
# Aug-2010
# 604885
# ['Sep-2010', '-216386']
# Sep-2010
# -216386
# ['Oct-2010', '477532']
# Oct-2010
# 477532
# ['Nov-2010', '893810']
# Nov-2010
# 893810
# ['Dec-2010', '-80353']
# Dec-2010
# -80353
# ['Jan-2011', '779806']
# Jan-2011
# 779806
# ['Feb-2011', '-335203']
# Feb-2011
# -335203
# ['Mar-2011', '697845']
# Mar-2011
# 697845
# ['Apr-2011', '793163']
# Apr-2011
# 793163
# ['May-2011', '485070']
# May-2011
# 485070
# ['Jun-2011', '584122']
# Jun-2011
# 584122
# ['Jul-2011', '62729']
# Jul-2011
# 62729
# ['Aug-2011', '668179']
# Aug-2011
# 668179
# ['Sep-2011', '899906']
# Sep-2011
# 899906
# ['Oct-2011', '834719']
# Oct-2011
# 834719
# ['Nov-2011', '132003']
# Nov-2011
# 132003
# ['Dec-2011', '309978']
# Dec-2011
# 309978
# ['Jan-2012', '-755566']
# Jan-2012
# -755566
# ['Feb-2012', '1170593']
# Feb-2012
# 1170593
# ['Mar-2012', '252788']
# Mar-2012
# 252788
# ['Apr-2012', '1151518']
# Apr-2012
# 1151518
# ['May-2012', '817256']
# May-2012
# 817256
# ['Jun-2012', '570757']
# Jun-2012
# 570757
# ['Jul-2012', '506702']
# Jul-2012
# 506702
# ['Aug-2012', '-1022534']
# Aug-2012
# -1022534
# ['Sep-2012', '475062']
# Sep-2012
# 475062
# ['Oct-2012', '779976']
# Oct-2012
# 779976
# ['Nov-2012', '144175']
# Nov-2012
# 144175
# ['Dec-2012', '542494']
# Dec-2012
# 542494
# ['Jan-2013', '359333']
# Jan-2013
# 359333
# ['Feb-2013', '321469']
# Feb-2013
# 321469
# ['Mar-2013', '67780']
# Mar-2013
# 67780
# ['Apr-2013', '471435']
# Apr-2013
# 471435
# ['May-2013', '565603']
# May-2013
# 565603
# ['Jun-2013', '872480']
# Jun-2013
# 872480
# ['Jul-2013', '789480']
# Jul-2013
# 789480
# ['Aug-2013', '999942']
# Aug-2013
# 999942
# ['Sep-2013', '-1196225']
# Sep-2013
# -1196225
# ['Oct-2013', '268997']
# Oct-2013
# 268997
# ['Nov-2013', '-687986']
# Nov-2013
# -687986
# ['Dec-2013', '1150461']
# Dec-2013
# 1150461
# ['Jan-2014', '682458']
# Jan-2014
# 682458
# ['Feb-2014', '617856']
# Feb-2014
# 617856
# ['Mar-2014', '824098']
# Mar-2014
# 824098
# ['Apr-2014', '581943']
# Apr-2014
# 581943
# ['May-2014', '132864']
# May-2014
# 132864
# ['Jun-2014', '448062']
# Jun-2014
# 448062
# ['Jul-2014', '689161']
# Jul-2014
# 689161
# ['Aug-2014', '800701']
# Aug-2014
# 800701
# ['Sep-2014', '1166643']
# Sep-2014
# 1166643
# ['Oct-2014', '947333']
# Oct-2014
# 947333
# ['Nov-2014', '578668']
# Nov-2014
# 578668
# ['Dec-2014', '988505']
# Dec-2014
# 988505
# ['Jan-2015', '1139715']
# Jan-2015
# 1139715
# ['Feb-2015', '1029471']
# Feb-2015
# 1029471
# ['Mar-2015', '687533']
# Mar-2015
# 687533
# ['Apr-2015', '-524626']
# Apr-2015
# -524626
# ['May-2015', '158620']
# May-2015
# 158620
# ['Jun-2015', '87795']
# Jun-2015
# 87795
# ['Jul-2015', '423389']
# Jul-2015
# 423389
# ['Aug-2015', '840723']
# Aug-2015
# 840723
# ['Sep-2015', '568529']
# Sep-2015
# 568529
# ['Oct-2015', '332067']
# Oct-2015
# 332067
# ['Nov-2015', '989499']
# Nov-2015
# 989499
# ['Dec-2015', '778237']
# Dec-2015
# 778237
# ['Jan-2016', '650000']
# Jan-2016
# 650000
# ['Feb-2016', '-1100387']
# Feb-2016
# -1100387
# ['Mar-2016', '-174946']
# Mar-2016
# -174946
# ['Apr-2016', '757143']
# Apr-2016
# 757143
# ['May-2016', '445709']
# May-2016
# 445709
# ['Jun-2016', '712961']
# Jun-2016
# 712961
# ['Jul-2016', '-1163797']
# Jul-2016
# -1163797
# ['Aug-2016', '569899']
# Aug-2016
# 569899
# ['Sep-2016', '768450']
# Sep-2016
# 768450
# ['Oct-2016', '102685']
# Oct-2016
# 102685
# ['Nov-2016', '795914']
# Nov-2016
# 795914
# ['Dec-2016', '60988']
# Dec-2016
# 60988
# ['Jan-2017', '138230']
# Jan-2017
# 138230
# ['Feb-2017', '671099']
# Feb-2017
# 671099

# %%
# Test to see if list works 
print(pnls)
# Out:
# [867884, 984655, 322013, -69417, 310503, 522857, 1033096, 604885, -216386, 477532, 893810, -80353, 779806, -335203, 697845, 793163, 485070, 584122, 62729, 668179, 899906, 834719, 132003, 309978, -755566, 1170593, 252788, 1151518, 817256, 570757, 506702, -1022534, 475062, 779976, 144175, 542494, 359333, 321469, 67780, 471435, 565603, 872480, 789480, 999942, -1196225, 268997, -687986, 1150461, 682458, 617856, 824098, 581943, 132864, 448062, 689161, 800701, 1166643, 947333, 578668, 988505, 1139715, 1029471, 687533, -524626, 158620, 87795, 423389, 840723, 568529, 332067, 989499, 778237, 650000, -1100387, -174946, 757143, 445709, 712961, -1163797, 569899, 768450, 102685, 795914, 60988, 138230, 671099]

# %%
print(len(pnls))
#Find length of how many months for first answer
# Out:
# 86

# %%
# Separate the profitable months from the unprofitable and sort them into their repsective lists


for monthly_pnl in pnls:
    
    if minimum == 0:
        minimum = monthly_pnl
    elif monthly_pnl < minimum:
        minimum = monthly_pnl
    elif monthly_pnl > maximum:
        maximum = monthly_pnl
        
    if monthly_pnl > 0:
        profitable_months.append(monthly_pnl)
    elif monthly_pnl <= 0:
        unprofitable_months.append(monthly_pnl)

# %%
# Test to see if profitable months list works 
print(len(profitable_months))

print(profitable_months)
# Out:
# 74
# [867884, 984655, 322013, 310503, 522857, 1033096, 604885, 477532, 893810, 779806, 697845, 793163, 485070, 584122, 62729, 668179, 899906, 834719, 132003, 309978, 1170593, 252788, 1151518, 817256, 570757, 506702, 475062, 779976, 144175, 542494, 359333, 321469, 67780, 471435, 565603, 872480, 789480, 999942, 268997, 1150461, 682458, 617856, 824098, 581943, 132864, 448062, 689161, 800701, 1166643, 947333, 578668, 988505, 1139715, 1029471, 687533, 158620, 87795, 423389, 840723, 568529, 332067, 989499, 778237, 650000, 757143, 445709, 712961, 569899, 768450, 102685, 795914, 60988, 138230, 671099]

# %%
# Test to see if list of unprofitable months work 
print(len(unprofitable_months))

print(unprofitable_months)
# Out:
# 12
# [-69417, -216386, -80353, -335203, -755566, -1022534, -1196225, -687986, -524626, -1100387, -174946, -1163797]

# %%
# Sum of profits and losses test to find the second part to the question 
total = sum(pnls)
print(total)

print(max(profitable_months))
# Out:
# 38382578
# 1170593

# %%
#Make sure first answer to the question matches prompt 
count = len(pnls)
print(count)
# Out:
# 86

# %%
print(pnls)

counter = 0
# Out:
# [867884, 984655, 322013, -69417, 310503, 522857, 1033096, 604885, -216386, 477532, 893810, -80353, 779806, -335203, 697845, 793163, 485070, 584122, 62729, 668179, 899906, 834719, 132003, 309978, -755566, 1170593, 252788, 1151518, 817256, 570757, 506702, -1022534, 475062, 779976, 144175, 542494, 359333, 321469, 67780, 471435, 565603, 872480, 789480, 999942, -1196225, 268997, -687986, 1150461, 682458, 617856, 824098, 581943, 132864, 448062, 689161, 800701, 1166643, 947333, 578668, 988505, 1139715, 1029471, 687533, -524626, 158620, 87795, 423389, 840723, 568529, 332067, 989499, 778237, 650000, -1100387, -174946, 757143, 445709, 712961, -1163797, 569899, 768450, 102685, 795914, 60988, 138230, 671099]

# %%
#Make a list called monthy_change in order to find the marginal differences by month in the following for loop

#Make a list called monthy_change in order to find the marginal differences by month in the following for loop

monthly_change = []
previous_month = pnls[0]
current_month = 0
counter = 0
months_change = 0

for x in pnls:
    #previous_month = x
    counter += 1
    if previous_month != 0:
        current_month = x
        print("Previous Mon:" +str(previous_month))
        print("Current Month:" + str(current_month))
        months_change = int(current_month - previous_month)
        print(months_change)
        previous_month = x
    monthly_change.append(months_change)
    

    
monthly_change.pop(0)

print(monthly_change)
# Out:
# Previous Mon:867884
# Current Month:867884
# 0
# Previous Mon:867884
# Current Month:984655
# 116771
# Previous Mon:984655
# Current Month:322013
# -662642
# Previous Mon:322013
# Current Month:-69417
# -391430
# Previous Mon:-69417
# Current Month:310503
# 379920
# Previous Mon:310503
# Current Month:522857
# 212354
# Previous Mon:522857
# Current Month:1033096
# 510239
# Previous Mon:1033096
# Current Month:604885
# -428211
# Previous Mon:604885
# Current Month:-216386
# -821271
# Previous Mon:-216386
# Current Month:477532
# 693918
# Previous Mon:477532
# Current Month:893810
# 416278
# Previous Mon:893810
# Current Month:-80353
# -974163
# Previous Mon:-80353
# Current Month:779806
# 860159
# Previous Mon:779806
# Current Month:-335203
# -1115009
# Previous Mon:-335203
# Current Month:697845
# 1033048
# Previous Mon:697845
# Current Month:793163
# 95318
# Previous Mon:793163
# Current Month:485070
# -308093
# Previous Mon:485070
# Current Month:584122
# 99052
# Previous Mon:584122
# Current Month:62729
# -521393
# Previous Mon:62729
# Current Month:668179
# 605450
# Previous Mon:668179
# Current Month:899906
# 231727
# Previous Mon:899906
# Current Month:834719
# -65187
# Previous Mon:834719
# Current Month:132003
# -702716
# Previous Mon:132003
# Current Month:309978
# 177975
# Previous Mon:309978
# Current Month:-755566
# -1065544
# Previous Mon:-755566
# Current Month:1170593
# 1926159
# Previous Mon:1170593
# Current Month:252788
# -917805
# Previous Mon:252788
# Current Month:1151518
# 898730
# Previous Mon:1151518
# Current Month:817256
# -334262
# Previous Mon:817256
# Current Month:570757
# -246499
# Previous Mon:570757
# Current Month:506702
# -64055
# Previous Mon:506702
# Current Month:-1022534
# -1529236
# Previous Mon:-1022534
# Current Month:475062
# 1497596
# Previous Mon:475062
# Current Month:779976
# 304914
# Previous Mon:779976
# Current Month:144175
# -635801
# Previous Mon:144175
# Current Month:542494
# 398319
# Previous Mon:542494
# Current Month:359333
# -183161
# Previous Mon:359333
# Current Month:321469
# -37864
# Previous Mon:321469
# Current Month:67780
# -253689
# Previous Mon:67780
# Current Month:471435
# 403655
# Previous Mon:471435
# Current Month:565603
# 94168
# Previous Mon:565603
# Current Month:872480
# 306877
# Previous Mon:872480
# Current Month:789480
# -83000
# Previous Mon:789480
# Current Month:999942
# 210462
# Previous Mon:999942
# Current Month:-1196225
# -2196167
# Previous Mon:-1196225
# Current Month:268997
# 1465222
# Previous Mon:268997
# Current Month:-687986
# -956983
# Previous Mon:-687986
# Current Month:1150461
# 1838447
# Previous Mon:1150461
# Current Month:682458
# -468003
# Previous Mon:682458
# Current Month:617856
# -64602
# Previous Mon:617856
# Current Month:824098
# 206242
# Previous Mon:824098
# Current Month:581943
# -242155
# Previous Mon:581943
# Current Month:132864
# -449079
# Previous Mon:132864
# Current Month:448062
# 315198
# Previous Mon:448062
# Current Month:689161
# 241099
# Previous Mon:689161
# Current Month:800701
# 111540
# Previous Mon:800701
# Current Month:1166643
# 365942
# Previous Mon:1166643
# Current Month:947333
# -219310
# Previous Mon:947333
# Current Month:578668
# -368665
# Previous Mon:578668
# Current Month:988505
# 409837
# Previous Mon:988505
# Current Month:1139715
# 151210
# Previous Mon:1139715
# Current Month:1029471
# -110244
# Previous Mon:1029471
# Current Month:687533
# -341938
# Previous Mon:687533
# Current Month:-524626
# -1212159
# Previous Mon:-524626
# Current Month:158620
# 683246
# Previous Mon:158620
# Current Month:87795
# -70825
# Previous Mon:87795
# Current Month:423389
# 335594
# Previous Mon:423389
# Current Month:840723
# 417334
# Previous Mon:840723
# Current Month:568529
# -272194
# Previous Mon:568529
# Current Month:332067
# -236462
# Previous Mon:332067
# Current Month:989499
# 657432
# Previous Mon:989499
# Current Month:778237
# -211262
# Previous Mon:778237
# Current Month:650000
# -128237
# Previous Mon:650000
# Current Month:-1100387
# -1750387
# Previous Mon:-1100387
# Current Month:-174946
# 925441
# Previous Mon:-174946
# Current Month:757143
# 932089
# Previous Mon:757143
# Current Month:445709
# -311434
# Previous Mon:445709
# Current Month:712961
# 267252
# Previous Mon:712961
# Current Month:-1163797
# -1876758
# Previous Mon:-1163797
# Current Month:569899
# 1733696
# Previous Mon:569899
# Current Month:768450
# 198551
# Previous Mon:768450
# Current Month:102685
# -665765
# Previous Mon:102685
# Current Month:795914
# 693229
# Previous Mon:795914
# Current Month:60988
# -734926
# Previous Mon:60988
# Current Month:138230
# 77242
# Previous Mon:138230
# Current Month:671099
# 532869
# [116771, -662642, -391430, 379920, 212354, 510239, -428211, -821271, 693918, 416278, -974163, 860159, -1115009, 1033048, 95318, -308093, 99052, -521393, 605450, 231727, -65187, -702716, 177975, -1065544, 1926159, -917805, 898730, -334262, -246499, -64055, -1529236, 1497596, 304914, -635801, 398319, -183161, -37864, -253689, 403655, 94168, 306877, -83000, 210462, -2196167, 1465222, -956983, 1838447, -468003, -64602, 206242, -242155, -449079, 315198, 241099, 111540, 365942, -219310, -368665, 409837, 151210, -110244, -341938, -1212159, 683246, -70825, 335594, 417334, -272194, -236462, 657432, -211262, -128237, -1750387, 925441, 932089, -311434, 267252, -1876758, 1733696, 198551, -665765, 693229, -734926, 77242, 532869]

# %%
average_monthly_change = round(sum(monthly_change) / len(monthly_change), 2)

print(average_monthly_change)
# Out:
# -2315.12

# %%
monthly_inc = max(monthly_change)

# %%
monthly_dec = min(monthly_change)

# %%
print("Financial Analysis")

print("--------------------------")

print(f"Total Months: {count}")

print(f"Total: ${total}")

print(f"Average Change: ${average_monthly_change}")

print(f"Greatest Increase in Profits: Feb-2012 (${monthly_inc})")

print(f"Greatest Decrease in Profits: Sep-2013 (${monthly_dec})")
# Out:
# Financial Analysis
# --------------------------
# Total Months: 86
# Total: $38382578
# Average Change: $-2315.12
# Greatest Increase in Profits: Feb-2012 ($1926159)
# Greatest Decrease in Profits: Sep-2013 ($-2196167)
